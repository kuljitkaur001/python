# %% [markdown]
# # if oonditional statement

# %%
a = int(input("enter you age "))
if a>20:
    print(":- \n you can drive")
# Out:
# enter you age  45
# :-
#  you can drive

# %% [markdown]
# # if else sattement

# %%
age = int(input("enter your age "))
if a>18:
    print("you can drive")

else:
    print("you can not drive")
# Out:
# enter your age  65
# you can drive

# %% [markdown]
# # if , elif , else statement

# %%
age3 = int(input("enter your age "))
if age > 18:
    print("you can drive. thnakyou")

elif age < 18:
    print("you cant drive dear, wait for your time ")

else: 
    print("enjoy")

# %% [markdown]
# # nested if

# %%
cgpa = float(input("enter you current CGPA"))
if cgpa >= 7.5:
    print("you have good cgpa, please ans some question below ")

    b = int(input("enter your backlogs , (in numbers only )"))
    if b == 0:
        print("good, please look at other questions too ")

        c = float(input("enter your 10th percentage"))
        if c>70:
            print("you are very close here, few more questions are in way ")

            c = float(input("enter your 10th percentage"))
            if c>70:
                print("you are eligible")

else:
    print("sorry try next time")
# Out:
# enter you current CGPA e
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cgpa = float(input("enter you current CGPA"))
#       2 if cgpa >= 7.5:
#       3     print("you have good cgpa, please ans some question below ")
#
# ValueError: could not convert string to float: 'e'

# %% [markdown]
# # printing good morning, whne time in between 00:00 to 12 am , good aftermoon when time between 12 pm to 4 pm , and good evebubg , when time is between 4pm to 11 pm

# %%
time = int(input("enter current time :  "))
if time > 1 and time < 4:
    print("good afternoon, kuljit")

elif time > 4 and time < 12:
    print("good evening")

else:
    print("good morning ")
# Out:
# enter current time :   7
# good evening

# %% [markdown]
# # priblem 3:  checking if purchase possible or not

# %%
money = float(input("enter your money ammount"))
purchase_ammount = float(input("enter a purchase ammount "))
if money >= purchase_ammount:
    print("yes you can buy ...")

else:
    print("sorry bro gate is open for you, and leave the showroom ")
# Out:
# enter your money ammount 333
# enter a purchase ammount  666
# sorry bro gate is open for you, and leave the showroom

# %% [markdown]
# #### priblem 4 : checking if number is even or odd

# %%
number = int(input("enter any of the number "))
if number % 2 == 0 :
    print("number is even")
else:
    print("number is odd ")
# Out:
# enter any of the number  23
# number is odd

# %% [markdown]
# #### finding a number greater from 3 numbers

# %%
a = int(input("enter number 1 : "))
b = int(input("enter number 2 : "))
c = int(input("enter number 3 : "))

if a > b and a > c:
    print("a is greater number\n")
elif b > a and b > c:
    print("b is greater number\n")
elif c > b and c > a:
    print("c is greater number\n")
else:
    print("you did it ")
# Out:
# enter number 1 :  12
# enter number 2 :  34
# enter number 3 :  68
# c is greater number

# %% [markdown]
# #### checking if a number is primne or not

# %% [markdown]
# ##### it must not be divisble by any number.....
# # it must divides by their own table
# # 2 is prime number

# %%
a = 7
# b = int(input("enter any number"))
# if a > :
    # print(a,"number is greater than 1  , proceed mext   ")

if a % (a-1) == 0:
    print("not prime ")

elif a % (a-2) == 0 :
    print("not prime" )
elif a % (a-3) == 0 :
    print("not prime" )
elif a % (a-4) == 0 :
    print("not prime" )
elif a % (a-5) == 0 :
    print("not prime ")
    
elif a % (a-6) == 0 :
    print("not prime" )
    
else: 
    print("a is prime ")
# Out:
# not prime

# %%
z = 15
for i in range(2,z): # i = 2 , 
    if z % i == 0: # 15%2 == 1 (false) , here the else block refers to for loop , 15%3 == 0 (true) hence prints not prime 
        print(" not prime")
        break

else:
        print("prime")
# Out:
#  not prime

# %% [markdown]
# ##### if a year is leap or not?

# %%
year = int(input("enter the year that you want to check if leap or not "))

if year % 4 == 0 :
    print("this is a leap year ")

else:
    printa("this is not a leap year ")
# Out:
# enter the year that you want to check if leap or not  2004
# this is a leap year

# %% [markdown]
# #### problem 5 : check if string has less than 10 characters or not

# %%
text  = "priayankabhikhan"
# length = len(text)

if len(text) == 10:
    print("yes string has length of character 10 ")

else:
    print("string has less than 10 character ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 text  = "priayankabhikhan"
#       2 # length = len(text)
# ----> 4 if len(text) == 10:
#       5     print("yes string has length of character 10 ")
#       7 else:
#
# TypeError: 'int' object is not callable

# %% [markdown]
# #### problm 6: checking if any 2 numbers are poistive or negative

# %%
print("welcome to number testing game")
x = int(input("enter number 1 "))
y = int(input("enter number 2 "))

if x < 1 and y < 1:
    print(" x and y both are negative numbers ")

elif x < 1  and y > 1:
    print(f"{x} is negative and {y} is positve")

elif x > 1 and  y <1:
    print(f"{x} is positivr and {y} is negative")
    

else:
    print("x and y both are positive numbers ")
# Out:
# welcome to number testing game
# enter number 1  2
# enter number 2  3
# x and y both are positive numbers

# %% [markdown]
# #### problem 7 : detecting spam commnts

# %%
spam_comment = input("enter any comment that you wnat to detect : ")
cmt1 = "buy one get one free"
cmt2 = "order now"
cmt3 = "your bank account is creditted"
cmt4 = "you have new client "
cmt5 = "you got many comments and likes "

if(cmt1,cmt2,cmt3,cmt4,cmt5):
    print("\n yes this is a spam comment")

else:
    print("\n no this is genuine one ")
# Out:
# enter any comment that you wnat to detect :  buy now
#  yes this is a spam comment

# %% [markdown]
# #### problem 5: checking student  is pass in 10th exam or not

# %%
#### maths = float(input("enter you maths marks "))
english = float(input("enter you English marks "))
hindi = float(input("enter you Hindi marks "))
Punjabi = float(input("enter you punjabi marks "))
computer = float(input("enter you Computer marks "))
science = float(input("enter you Science marks "))
sst = float(input("enter you sst marks "))
history = float(input("enter you history marks "))
civics = float(input("enter you civics marks "))
avg_percentage = ((maths+english+hindi+computer+science+sst+history+civics)/900*100)

print("your percentage is : ", avg_percentage)

if avg_percentage < 33 :
    print("you are fail, report on +919843636 this number for further assistence. ")

else:
    print("you are pass in your 10th exam")
# Out:
# enter you English marks  23
# enter you Hindi marks  34
# enter you punjabi marks  56
# enter you Computer marks  67
# enter you Science marks  56
# enter you sst marks  45
# enter you history marks  34
# enter you civics marks  78
# your percentage is :  40.11111111111111
# you are pass in your 10th exam
